# %% [markdown]
# <a href="https://colab.research.google.com/github/RODIV45/Data-Analysis-with-Python-GFG/blob/main/null_value_handle_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/airports.csv"
df=pd.read_csv(path)

# %%
df
# Out:
#            id    ident           type                                name  \
# 0        6523      00A       heliport                   Total Rf Heliport
# 1      323361     00AA  small_airport                Aero B Ranch Airport
# 2        6524     00AK  small_airport                        Lowell Field
# 3        6525     00AL  small_airport                        Epps Airpark
# 4        6526     00AR         closed  Newport Hospital & Clinic Heliport
# ...       ...      ...            ...                                 ...
# 74458   46378  ZZ-0001       heliport                     Sealand Helipad
# 74459  307326  ZZ-0002  small_airport           Glorioso Islands Airstrip
# 74460  346788  ZZ-0003  small_airport               Fainting Goat Airport
# 74461  342102     ZZZW         closed              Scandium City Heliport
# 74462  313629     ZZZZ  small_airport              Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# ...

# %%
df.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.947733    -151.692524         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
df.isnull().sum()
#shows how many null rows under each column
# Out:
# id                       0
# ident                    0
# type                     0
# name                     0
# latitude_deg             0
# longitude_deg            0
# elevation_ft         14207
# continent            36027
# iso_country            259
# iso_region               0
# municipality          4986
# scheduled_service        0
# gps_code             33551
# iata_code            65602
# local_code           42339
# home_link            70913
# wikipedia_link       63700
# keywords             57997
# dtype: int64

# %%
df.iloc[:,6:7].values
# Out:
# array([[  11.],
#        [3435.],
#        [ 450.],
#        ...,
#        [ 690.],
#        [   4.],
#        [ 338.]])

# %%
impute=SimpleImputer(missing_values=np.nan,strategy='mean')
impute.fit(df.iloc[:,6:7].values)
# Out:
# SimpleImputer()

# %%
df.iloc[:,6:7]=impute.transform(df.iloc[:,6:7].values)

# %%
df.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.947733    -151.692524         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
df.isnull().sum()
# Out:
# id                       0
# ident                    0
# type                     0
# name                     0
# latitude_deg             0
# longitude_deg            0
# elevation_ft             0
# continent            36027
# iso_country            259
# iso_region               0
# municipality          4986
# scheduled_service        0
# gps_code             33551
# iata_code            65602
# local_code           42339
# home_link            70913
# wikipedia_link       63700
# keywords             57997
# dtype: int64

# %%
#see clearly above that elevation has np null values

# %%
impute=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
impute.fit(df.iloc[:,:].values)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
df.iloc[:,:]=impute.transform(df.iloc[:,:].values)

# %%
df.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0        AS          US      US-PA
# 1     38.704022    -101.473911        3435.0        AS          US      US-KS
# 2     59.947733    -151.692524         450.0        AS          US      US-AK
# 3     34.864799     -86.770302         820.0        AS          US      US-AL
# 4     35.608700     -91.254898         237.0        AS          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code  \
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# ident                0
# type                 0
# name                 0
# latitude_deg         0
# longitude_deg        0
# elevation_ft         0
# continent            0
# iso_country          0
# iso_region           0
# municipality         0
# scheduled_service    0
# gps_code             0
# iata_code            0
# local_code           0
# home_link            0
# wikipedia_link       0
# keywords             0
# dtype: int64

# %%
df
# Out:
#            id    ident           type                                name  \
# 0        6523      00A       heliport                   Total Rf Heliport
# 1      323361     00AA  small_airport                Aero B Ranch Airport
# 2        6524     00AK  small_airport                        Lowell Field
# 3        6525     00AL  small_airport                        Epps Airpark
# 4        6526     00AR         closed  Newport Hospital & Clinic Heliport
# ...       ...      ...            ...                                 ...
# 74458   46378  ZZ-0001       heliport                     Sealand Helipad
# 74459  307326  ZZ-0002  small_airport           Glorioso Islands Airstrip
# 74460  346788  ZZ-0003  small_airport               Fainting Goat Airport
# 74461  342102     ZZZW         closed              Scandium City Heliport
# 74462  313629     ZZZZ  small_airport              Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# ...

# %%
#now all null values including strings, categorial and numeric are handled

# %%
#if number of nullrows are less in number then we can go for df.dropna()
#this deletes the less significant null rows under the columns
